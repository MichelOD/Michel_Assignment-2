# %%
import datetime
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import math
from pathlib import Path
from matplotlib.ticker import FormatStrFormatter
from dateutil.parser import parse
from scipy import stats

# %%
# %load_ext autoreload
# %autoreload 2

# %%
list(Path().cwd().glob('*csv'))

# %%
df_Jan_18 = pd.read_csv("UoR_Data (13).csv",header=[0,1],index_col=0)
df_Jan_18=df_Jan_18.droplevel(1,axis=1)
df_Jan_18.index=pd.to_datetime(df_Jan_18.index)
df_Jan_18.head(5)
# Out:
# TimeStamp               WS      L        zL     C_CO2   ustar  Tsonic  \
# 2018-01-01 00:30:00  3.121  115.3  0.025162  0.000562  0.4002   288.0
# 2018-01-01 01:00:00  3.017   62.0  0.046779  0.000563  0.2773   288.0
# 2018-01-01 01:30:00  3.056  194.7  0.014897  0.000566  0.4834   287.0
# 2018-01-01 02:00:00  3.272  296.9  0.009768  0.000571  0.4048   287.0
# 2018-01-01 02:30:00  2.904   32.9  0.088228  0.000558  0.2329   287.0
#
# TimeStamp                  q  sd_C_CO2    F_CO2     Q_E    Q_H
# 2018-01-01 00:30:00  0.00507  0.000001  -1.1648 -3.9303 -70.13
# 2018-01-01 01:00:00  0.00493  0.000001   0.4232 -2.5736 -42.91
# 2018-01-01 01:30:00  0.00494  0.000004   3.0581 -2.6173 -72.43
# 2018-01-01 02:00:00      NaN  0.000010  -6.1403     NaN -28.23
# 2018-01-01 02:30:00      NaN  0.000018 -31.5957     NaN -47.36

# %%
df_Jan_18.columns
# Out:
# Index(['L', 'C_CO2', 'ustar', 'sd_C_CO2', 'F_CO2', 'Q_E', 'Q_H'], dtype='object', name='TimeStamp')

# %%
plt.figure(figsize=(15,10))
plt.scatter(df_Jan_18.F_CO2,df_Jan_18.q)
plt.title('Correlation between CO2 Flux with Humidity in January 2018', fontsize=17)    
plt.xlabel('Co2 Flux (umolm$^{-2}$s$^{-1}$)', fontsize=14)
plt.ylabel('Humidity (Kg Kg$^{-1}$)', fontsize=14)
# Out:
# Text(0, 0.5, 'Humidity (Kg Kg$^{-1}$)')

# %%
df_Jan_18.F_CO2.describe()
# Out:
# count    204.000000
# mean       0.310837
# std       14.527643
# min      -55.385000
# 25%       -3.079025
# 50%       -0.983100
# 75%        0.748125
# max      129.163600
# Name: F_CO2, dtype: float64

# %%
df_Apr_18.F_CO2.describe()
# Out:
# count    174.000000
# mean       1.122322
# std       39.146924
# min      -78.971000
# 25%       -9.125825
# 50%       -1.611200
# 75%        1.098825
# max      283.533800
# Name: F_CO2, dtype: float64

# %%
df_Jul_18.F_CO2.describe()
# Out:
# count    124.000000
# mean       0.345589
# std        2.671864
# min       -8.646200
# 25%       -0.607225
# 50%       -0.038850
# 75%        0.946525
# max       19.188800
# Name: F_CO2, dtype: float64

# %%
df_Oct_18.F_CO2.describe()
# Out:
# count    213.000000
# mean      -1.177368
# std        4.013629
# min      -12.743000
# 25%       -4.107600
# 50%       -0.143700
# 75%        1.349600
# max       19.774000
# Name: F_CO2, dtype: float64

# %%
df_Apr_18 = pd.read_csv("UoR_Data (1).csv",header=[0,1],index_col=0)
df_Apr_18=df_Apr_18.droplevel(1,axis=1)
df_Apr_18.index=pd.to_datetime(df_Apr_18.index)

df_Apr_18.head(5)
# Out:
# TimeStamp                  L     C_CO2   ustar      sd_C_CO2   F_CO2   Q_E  \
# 2018-04-01 00:30:00  604.207  0.000582  0.3823  9.570000e-07  1.1499  1.19
# 2018-04-01 01:00:00  347.893  0.000583  0.3059  1.070000e-06  1.0773  2.31
# 2018-04-01 01:30:00  192.637  0.000583  0.3463  9.320000e-07  0.5505  6.09
# 2018-04-01 02:00:00  388.474  0.000583  0.3393  8.600000e-07  1.2712  3.64
# 2018-04-01 02:30:00  235.571  0.000583  0.2124  1.140000e-06  0.0922  1.30
#
# TimeStamp              Q_H
# 2018-04-01 00:30:00 -11.19
# 2018-04-01 01:00:00  -9.88
# 2018-04-01 01:30:00 -25.71
# 2018-04-01 02:00:00 -11.93
# 2018-04-01 02:30:00  -4.83

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df_Jan_18.F_CO2)
plt.tick_params(labelsize= 18)
plt.title('Co2 Fluxes during a Week in January 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Co2 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)
# Out:
# Text(0, 0.5, 'Co2 Fluxes (umolm$^{-2}$s$^{-1}$)')

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df_Apr_18.F_CO2)
plt.tick_params(labelsize= 18)
plt.title('Co2 Fluxes during a Week in April 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Co2 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)
# Out:
# Text(0, 0.5, 'Co2 Fluxes (umolm$^{-2}$s$^{-1}$)')

# %%
df_Jul_18 = pd.read_csv("UoR_Data (14).csv",header=[0,1],index_col=0)
df_Jul_18=df_Jul_18.droplevel(1,axis=1)
df_Jul_18.index=pd.to_datetime(df_Jul_18.index)

df_Jul_18.head(5)
# Out:
# TimeStamp                WS      L        zL     C_CO2   ustar  Tsonic  \
# 2018-07-09 00:30:00
# 2018-07-09 01:00:00     NaN    NaN       NaN       NaN     NaN     NaN
# 2018-07-09 01:30:00  0.2796   3.27  0.885714  0.000590  0.0135   292.0
# 2018-07-09 02:00:00  0.1078  -5.15 -0.563489  0.000590  0.0465   292.0
# 2018-07-09 02:30:00  0.2579  -4.66 -0.622747  0.000596  0.0362   292.0
# 2018-07-09 03:00:00  0.2399 -12.70 -0.228399  0.000605  0.0298   291.0
#
# TimeStamp                  q  sd_C_CO2   F_CO2     Q_E    Q_H
# 2018-07-09 00:30:00
# 2018-07-09 01:00:00      NaN       NaN     NaN     NaN    NaN
# 2018-07-09 01:30:00  0.00919  0.000005 -0.0931  0.0815 -0.154
# 2018-07-09 02:00:00  0.00927  0.000004  0.4201  0.1725  4.006
# 2018-07-09 02:30:00  0.00929  0.000005 -0.3058  0.6989  2.097
# 2018-07-09 03:00:00  0.00929  0.000005 -0.4336  0.2637  0.427

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df_Jul_18.F_CO2)
plt.tick_params(labelsize= 18)
plt.title('Co2 Fluxes during a Week in July 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Co2 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)
# Out:
# Text(0, 0.5, 'Co2 Fluxes (umolm$^{-2}$s$^{-1}$)')

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df_Jul_18.WS)
plt.tick_params(labelsize= 18)
plt.title('Co2 Fluxes during a Week in July 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Co2 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)
# Out:
# Text(0, 0.5, 'Co2 Fluxes (umolm$^{-2}$s$^{-1}$)')

# %%
plt.figure(figsize=(15,10))
plt.scatter(df_Jul_18.F_CO2,df_Jul_18.q)
plt.title('Correlation between CO2 Flux with Humidity in July 2018', fontsize=17)    
plt.xlabel('Co2 Flux (umolm$^{-2}$s$^{-1}$)', fontsize=14)
plt.ylabel('Humidity (Kg Kg$^{-1}$)', fontsize=14)
# Out:
# Text(0, 0.5, 'Humidity (Kg Kg$^{-1}$)')

# %%
plt.figure(figsize=(15,10))
plt.scatter(df_Oct_18.F_CO2,df_Oct_18.q)
plt.title('Correlation between CO2 Flux with Humidity', fontsize=17)    
plt.xlabel('Co2 Flux (umolm$^{-2}$s$^{-1}$)', fontsize=14)
plt.ylabel('Humidity (Kg Kg$^{-1}$)', fontsize=14)
# Out:
# Text(0, 0.5, 'Humidity (Kg Kg$^{-1}$)')

# %%
df_Oct_18 = pd.read_csv("UoR_Data (15).csv",header=[0,1],index_col=0)
df_Oct_18=df_Oct_18.droplevel(1,axis=1)
df_Oct_18.index=pd.to_datetime(df_Oct_18.index)

df_Oct_18.head(5)
# Out:
# TimeStamp               WS     L      zL     C_CO2   ustar  Tsonic        q  \
# 2018-10-01 00:30:00
# 2018-10-01 01:00:00    NaN   NaN     NaN       NaN     NaN     NaN      NaN
# 2018-10-01 01:30:00  1.575  73.4  0.0395  0.000567  0.2530   287.0  0.00526
# 2018-10-01 02:00:00  0.920  74.6  0.0389  0.000569  0.2692   287.0  0.00525
# 2018-10-01 02:30:00  1.184  45.4  0.0639  0.000569  0.2133   287.0  0.00524
# 2018-10-01 03:00:00  1.004  54.3  0.0534  0.000572  0.2615   287.0  0.00524
#
# TimeStamp            sd_C_CO2   F_CO2    Q_E      Q_H
# 2018-10-01 00:30:00
# 2018-10-01 01:00:00       NaN     NaN    NaN      NaN
# 2018-10-01 01:30:00  0.000001  1.2880  0.798 -29.0862
# 2018-10-01 02:00:00  0.000001  0.5900 -3.689 -34.4443
# 2018-10-01 02:30:00  0.000002  2.5247 -2.993 -28.1288
# 2018-10-01 03:00:00  0.000002  1.9692  1.579 -43.2977

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df_Oct_18.F_CO2)
plt.tick_params(labelsize= 18)
plt.title('Co2 Fluxes during a Week in October 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Co2 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)
# Out:
# Text(0, 0.5, 'Co2 Fluxes (umolm$^{-2}$s$^{-1}$)')

# %%
fig,axs=plt.subplots(2,2,figsize=(20,15))
plt.subplots_adjust(hspace=0.3,wspace=0.3)
ax1=axs[0][0]
df_Jan_18.F_CO2.plot(ax=ax1)
ax1.set_title('(a) CO2 Flux during a Week in January 2018',fontsize=15)
ax1.set_xlabel('Time (Days)', fontsize=12)
ax1.set_ylabel('CO2 Flux (umolm$^{-2}$s$^{-1}$)',fontsize=12)

ax2=axs[0][1]
df_Apr_18.F_CO2.plot(ax=ax2)
#df_Apr.Q_E.plot(ax=ax2)
ax2.set_title('(b) CO2 Flux during a Week in April 2018',fontsize=15)
ax2.set_xlabel('Time (Days)', fontsize=12)
ax2.set_ylabel('CO2 Flux (umolm$^{-2}$s$^{-1}$)',fontsize=12)

ax3=axs[1][0]
df_Jul_18.F_CO2.plot(ax=ax3)
ax3.set_title('(c) CO2 Flux during a Week in July 2018',fontsize=15)
ax3.set_xlabel('Time (Days)', fontsize=12)
ax3.set_ylabel('CO2 Flux (umolm$^{-2}$s$^{-1}$)',fontsize=12)

ax4=axs[1][1]
df_Oct_18.F_CO2.plot(ax=ax4)
ax4.set_title('(d) CO2 Flux during a Week in October 2018',fontsize=15)
ax4.set_xlabel('Time (Days)', fontsize=12)
ax4.set_ylabel('CO2 Flux (umolm$^{-2}$s$^{-1}$)',fontsize=12)
# Out:
# Text(0, 0.5, 'CO2 Flux (umolm$^{-2}$s$^{-1}$)')

# %%
df_Jan = pd.read_csv("UoR_Data (4).csv",header=[0,1],index_col=0)
df_Jan=df_Jan.droplevel(1,axis=1)
df_Jan.index=pd.to_datetime(df_Jan.index)

df_Jan.head(5)
# Out:
# TimeStamp                  L     C_CO2   ustar  nSamples  sd_C_CO2    F_CO2  \
# 2018-01-10 00:30:00   69.640  0.000596  0.1694   18000.0  0.000013  -16.193
# 2018-01-10 01:00:00  228.611  0.000584  0.2389   18000.0  0.000010   -3.949
# 2018-01-10 01:30:00 -436.968  0.000585  0.2719   18000.0  0.000011  -43.061
# 2018-01-10 02:00:00   36.574  0.000848  0.2521   18000.0  0.000020  143.911
# 2018-01-10 02:30:00  603.227  0.000888  0.2026   18000.0  0.000013   -0.847
#
# TimeStamp            Q_E      Q_H
# 2018-01-10 00:30:00  NaN -10.2751
# 2018-01-10 01:00:00  NaN  -8.8261
# 2018-01-10 01:30:00  NaN   6.8205
# 2018-01-10 02:00:00  NaN -65.1174
# 2018-01-10 02:30:00  NaN  -2.0574

# %%
df_Rain_Jan = pd.read_csv("UoR_Data (12).csv",header=[0,1],index_col=0)
df_Rain_Jan=df_Rain_Jan.droplevel(1,axis=1)
df_Rain_Jan.index=pd.to_datetime(df_Rain_Jan.index)

df_Rain_Jan.head(5)
# Out:
# TimeStamp                L        zL     C_CO2  ustar  Tsonic        q  \
# 2018-01-07 00:30:00  126.5  0.022921  0.000575  0.377   286.0  0.00361
# 2018-01-07 01:00:00  497.9  0.005825  0.000575  0.510   286.0  0.00364
# 2018-01-07 01:30:00  316.3  0.009169  0.000575  0.428   286.0  0.00362
# 2018-01-07 02:00:00  364.1  0.007965  0.000574  0.467   285.0  0.00354
# 2018-01-07 02:30:00  501.3  0.005785  0.000573  0.458   285.0  0.00345
#
# TimeStamp                sd_C_CO2    F_CO2     Q_E    Q_H
# 2018-01-07 00:30:00  9.210000e-07 -1.33795 -3.2849 -48.80
# 2018-01-07 01:00:00  7.960000e-07 -0.72234 -0.5859 -30.71
# 2018-01-07 01:30:00  8.550000e-07 -1.58177 -5.3304 -28.58
# 2018-01-07 02:00:00  8.840000e-07  0.37675  2.3011 -31.92
# 2018-01-07 02:30:00  8.160000e-07 -0.21257 -2.6141 -21.74

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df_Jan.F_CO2)
plt.tick_params(labelsize= 18)
plt.title('Co2 Fluxes on 10th January 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Co2 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)
# Out:
# Text(0, 0.5, 'Co2 Fluxes (umolm$^{-2}$s$^{-1}$)')

# %%
plt.figure(figsize=(15,10))
plt.scatter(df_Jan.F_CO2,df_Rain_Jan.q)

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df_Jan.q)
plt.tick_params(labelsize= 18)
plt.title('Co2 Fluxes on 10th January 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Co2 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)
# Out:
# Text(0, 0.5, 'Co2 Fluxes (umolm$^{-2}$s$^{-1}$)')

# %%
df_Apr = pd.read_csv("UoR_Data (5).csv", header=[0,1],index_col=0)
df_Apr=df_Apr.droplevel(1,axis=1)
df_Apr.index=pd.to_datetime(df_Apr.index)

df_Apr.head(5)
# Out:
# TimeStamp                L        zL     C_CO2   ustar  sd_C_CO2  F_CO2  \
# 2018-04-07 00:30:00  21.85  0.132699  0.000653  0.0508  0.000017  0.428
# 2018-04-07 01:00:00  10.91  0.265838  0.000630  0.0495  0.000009  2.300
# 2018-04-07 01:30:00   9.26  0.313298  0.000624  0.0610  0.000003  0.335
# 2018-04-07 02:00:00   3.12  0.928343  0.000646  0.0476  0.000012  3.356
# 2018-04-07 02:30:00  18.86  0.153795  0.000642  0.0610  0.000007  3.247
#
# TimeStamp               Q_E    Q_H
# 2018-04-07 00:30:00   0.274 -0.828
# 2018-04-07 01:00:00  -0.447 -1.533
# 2018-04-07 01:30:00  -0.107 -3.360
# 2018-04-07 02:00:00 -10.245 -4.649
# 2018-04-07 02:30:00  -3.397 -1.635

# %%
df_RH_Apr = pd.read_csv("UoR_Data (10).csv", header=[0,1],index_col=0)
df_RH_Apr=df_RH_Apr.droplevel(1,axis=1)
df_RH_Apr.index=pd.to_datetime(df_RH_Apr.index)

df_RH_Apr.head(5)
# Out:
# TimeStamp                L        zL     C_CO2   ustar  Tsonic        q  \
# 2018-04-07 00:30:00  21.85  0.132699  0.000653  0.0508   288.0  0.00602
# 2018-04-07 01:00:00  10.91  0.265838  0.000630  0.0495   288.0  0.00596
# 2018-04-07 01:30:00   9.26  0.313298  0.000624  0.0610   288.0  0.00593
# 2018-04-07 02:00:00   3.12  0.928343  0.000646  0.0476   287.0  0.00575
# 2018-04-07 02:30:00  18.86  0.153795  0.000642  0.0610   287.0  0.00580
#
# TimeStamp            sd_C_CO2  F_CO2     Q_E    Q_H
# 2018-04-07 00:30:00  0.000017  0.428   0.274 -0.828
# 2018-04-07 01:00:00  0.000009  2.300  -0.447 -1.533
# 2018-04-07 01:30:00  0.000003  0.335  -0.107 -3.360
# 2018-04-07 02:00:00  0.000012  3.356 -10.245 -4.649
# 2018-04-07 02:30:00  0.000007  3.247  -3.397 -1.635

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df_Apr.F_CO2, 'blue', label = 'CO2 Flux')
plt.plot(df_Apr.Q_E, 'orange', label= 'Latent Heat Flux')
plt.plot(df_Apr.Q_H, 'green', label= 'Sensible Heat Flux')

plt.tick_params(labelsize= 18)
plt.title('CO2 Fluxe on 7th April 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('CO2 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)
plt.legend()

# %%
plt.figure(figsize=(15,10))
plt.scatter(df_Apr.F_CO2,df_RH_Apr.q)

# %%
df_Jul = pd.read_csv("UoR_Data (6).csv",header=[0,1],index_col=0)
df_Jul=df_Jul.droplevel(1,axis=1)
df_Jul.index=pd.to_datetime(df_Jul.index)

df_Jul.head(5)
# Out:
# TimeStamp                 L     C_CO2   ustar  nSamples      sd_C_CO2  \
# 2018-07-10 00:30:00     NaN       NaN     NaN       0.0           NaN
# 2018-07-10 01:00:00     NaN       NaN     NaN       0.0           NaN
# 2018-07-10 01:30:00  1680.5  0.000542  0.3365   18000.0  7.180000e-07
# 2018-07-10 02:00:00  -394.2  0.000544  0.3137   18000.0  7.630000e-07
# 2018-07-10 02:30:00   255.4  0.000546  0.2245   18000.0  6.590000e-07
#
# TimeStamp              F_CO2     Q_E     Q_H
# 2018-07-10 00:30:00      NaN     NaN     NaN
# 2018-07-10 01:00:00      NaN     NaN     NaN
# 2018-07-10 01:30:00  0.60927  5.1011  -4.251
# 2018-07-10 02:00:00  1.20465 -5.1193  14.883
# 2018-07-10 02:30:00  0.92646  1.9252  -8.301

# %%
plt.figure(num=1, figsize=(15,10))
plt.plot(df_Jul.F_CO2)
plt.tick_params(labelsize= 18)
plt.title('C02 Fluxe on 10th July 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('C02 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)

# %%
df_Oct = pd.read_csv("UoR_Data (7).csv",header=[0,1],index_col=0)
df_Oct=df_Oct.droplevel(1,axis=1)
df_Oct.index=pd.to_datetime(df_Oct.index)
#pd.to_datetime(df_Oct['Time Stamp'], format='%Y%m%d%H%M')

df_Oct.head(6)
# Out:
# TimeStamp                L     C_CO2   ustar  nSamples  sd_C_CO2  F_CO2  \
# 2018-10-10 00:30:00    NaN       NaN     NaN       0.0       NaN    NaN
# 2018-10-10 01:00:00    NaN       NaN     NaN       0.0       NaN    NaN
# 2018-10-10 01:30:00  -2.51  0.000707  0.0412   18000.0  0.000007 -2.603
# 2018-10-10 02:00:00   6.07  0.000707  0.0301   18000.0  0.000011  2.555
# 2018-10-10 02:30:00  24.28  0.000739  0.0818   18000.0  0.000010 -2.004
# 2018-10-10 03:00:00   6.81  0.000748  0.0510   18000.0  0.000003  0.504
#
# TimeStamp              Q_E    Q_H
# 2018-10-10 00:30:00    NaN    NaN
# 2018-10-10 01:00:00    NaN    NaN
# 2018-10-10 01:30:00    NaN  4.432
# 2018-10-10 02:00:00    NaN -0.699
# 2018-10-10 02:30:00    NaN -3.587
# 2018-10-10 03:00:00 -7.661 -3.084

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df_Oct.F_CO2 )
plt.plot(df_Oct.Q_E, 'orange', label= 'Latent Heat Flux')
plt.plot(df_Oct.Q_H, 'green', label= 'Sensible Heat Flux')

plt.tick_params(labelsize= 18)
plt.title('C02 Fluxe on 10th October 2018',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Co2 Fluxes (umolm$^{-2}$s$^{-1}$)',fontsize=20)
# Out:
# Text(0, 0.5, 'Co2 Fluxes (umolm$^{-2}$s$^{-1}$)')

# %%
fig,axs=plt.subplots(2,2,figsize=(20,15))
plt.subplots_adjust(hspace=0.3,wspace=0.3)
ax1=axs[0][0]
df_Jan.F_CO2.plot(ax=ax1)
ax1.set_title('(a) 10th January 2018',fontsize=15)
ax1.set_xlabel('Time (Hours)',fontsize=12)
ax1.set_ylabel('CO2 Flux (umolm$^{-2}$s$^{-1}$)',fontsize=12)

ax2=axs[0][1]
df_Apr.F_CO2.plot(ax=ax2)
#df_Apr.Q_E.plot(ax=ax2)
ax2.set_title('(b) 7th April 2018',fontsize=15)
ax2.set_xlabel('Time (Hours)',fontsize=12)
ax2.set_ylabel('CO2 Flux (umolm$^{-2}$s$^{-1}$)',fontsize=12)

ax3=axs[1][0]
df_Jul.F_CO2.plot(ax=ax3)
ax3.set_title('(c) 10th July 2018',fontsize=15)
ax3.set_xlabel('Time (Hours)',fontsize=12)
ax3.set_ylabel('CO2 Flux (umolm$^{-2}$s$^{-1}$)',fontsize=12)

ax4=axs[1][1]
df_Oct.F_CO2.plot(ax=ax4)
ax4.set_title('(d) 10th October 2018',fontsize=15)
ax4.set_xlabel('Time (Hours)',fontsize=12)
ax4.set_ylabel('CO2 Flux (umolm$^{-2}$s$^{-1}$)',fontsize=12)
# Out:
# Text(0, 0.5, 'CO2 Flux (umolm$^{-2}$s$^{-1}$)')

# %%
df_Jan.F_CO2.describe()
# Out:
# count     39.000000
# mean       2.401692
# std       29.199599
# min      -43.061000
# 25%       -4.586500
# 50%       -1.263000
# 75%        1.335500
# max      143.911000
# Name: F_CO2, dtype: float64

# %%
df_Apr.F_CO2.describe()
# Out:
# count    48.000000
# mean     -1.889771
# std       6.181333
# min     -18.238000
# 25%      -5.024250
# 50%       0.381500
# 75%       1.612250
# max      13.461000
# Name: F_CO2, dtype: float64

# %%
df_Jul.F_CO2.describe()
# Out:
# count    40.000000
# mean     -0.241027
# std       1.859663
# min      -9.487720
# 25%      -0.774587
# 50%       0.178550
# 75%       0.653785
# max       2.145700
# Name: F_CO2, dtype: float64

# %%
df_Oct.F_CO2.describe()
# Out:
# count    40.000000
# mean     -1.130175
# std       6.522457
# min     -21.154000
# 25%      -3.909500
# 50%       1.401000
# 75%       2.618500
# max      11.117000
# Name: F_CO2, dtype: float64
